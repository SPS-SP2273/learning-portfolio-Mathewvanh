# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Storing Data (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Lists, Arrays & Dictionaries

# %% [markdown]
# ## 1.1 Let’s compare

# %% [markdown]
# ## 1.2 Accessing data from a list (or array)

# %% [markdown]
# ## 1.3 Accessing data from a dictionary

# %% [markdown]
# ## 1.4 Higher dimensional lists

# %% [markdown]
# # 2 Lists vs. Arrays

# %% [markdown]
# ## 2.1 Size

# %% [markdown]
# ## 2.2 Arrays are fussy about type

# %% [markdown]
# ## 2.3 Adding a number

# %% [markdown]
# ## 2.4 Adding another list

# %% [markdown]
# ## 2.5 Multiplying by a Number

# %% [markdown]
# ## 2.6 Squaring

# %% [markdown]
# ## 2.7 Asking questions

# %% [markdown]
# ## 2.8 Mathematics

# %% [markdown]
# # Exercises & Self-Assessment

# %% [markdown]
# Exercise 1

# %% [markdown]
# 1. Both lists and arrays store data in a container.different functions can be used to find the sum of all values in the list(provided they are the same type) and all the values in a numpy array.(They have by definition with only one type).
# 2. numpy arrays allows for mathematical operations to be done iteratively on each of its elements. But lists are treated as python objects and mathematical operations cannot be done automatically on the values in the list. They have to be accessed individually through the accessor function in a for loop, and manipulated to perform the operations.
# 3. A dictionary stores key,value pairs where the key can be used to access the hashed value inside the dictionary.

# %% [markdown]
# Exercise 2:

# %%
py_list = ["a1", "b2", "c3", "d4", "e5", "f6", "g7", "h8", "i9", "j10"]
for element in py_list:
    number = int(element[1:])
    if number%2!=0:
        print(element)

# %% [markdown]
# Exercise 3:

# %%
superhero_info = {"Natasha Romanoff": "Black Widow",
                  "Tony Stark": "Iron Man",
                  "Stephen Strange": "Doctor Strange"
                  }
for key in superhero_info.keys():
    superhero_info[key]=superhero_info[key].upper()
print(superhero_info)
# Out:
# {'Natasha Romanoff': 'BLACK WIDOW', 'Tony Stark': 'IRON MAN', 'Stephen Strange': 'DOCTOR STRANGE'}

# %% [markdown]
# Exercise 4:

# %%
numbers=[45, 60, 1, 30, 96, 1, 96, 57, 16, 1,
        99, 62, 86, 43, 42, 60, 59, 1, 1, 35,
        83, 47, 34, 28, 68, 23, 22, 92, 1, 79,
        1, 29, 94, 72, 46, 47, 1, 74, 32, 20,
        8, 37, 35, 1, 89, 29, 86, 19, 43, 61]  
cnt = 0                
for i in numbers:
    if i==1:
        cnt+=1
print(cnt)
# Out:
# 9

# %% [markdown]
# ## Footnotes
