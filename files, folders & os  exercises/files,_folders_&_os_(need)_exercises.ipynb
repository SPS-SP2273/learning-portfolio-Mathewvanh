# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# Task 1:

# %%
import os
import shutil
source_directory = '../os-collaboration-exercise-data/'
convert_dates = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
#print(f"{convert_dates['jan']}-dd-country")

for filename in os.listdir(source_directory):
    root,extension = os.path.splitext(filename)
    old_name = os.path.join(source_directory,filename)
    if not os.path.isfile(old_name):
        continue
    if extension!='.txt':
        continue
    parts = root.split('-')
    st = ''
    for i in parts[1]:
        if i=='_':
            st+='-'
        else:
            st+=i
    numeric_filename = f"{convert_dates[parts[0]]}-{st}.txt"
    new_name = os.path.join(source_directory,numeric_filename)
    shutil.move(old_name,new_name)

# %% [markdown]
# Task 2:

# %%
def rename_my_file(old_file_name):
    root,extension = os.path.splitext(old_file_name)
    if extension!='.txt':
        raise Exception("Only text files can be renamed")
    parts = root.split('-')
    st = ''
    for i in parts[1]:
        if i=='_':
            st+='-'
        else:
            st+=i
    numeric = f"{convert_dates[parts[0]]}-{st}.txt"
    return os.path.join(source_directory,numeric_filename)

# %% [markdown]
# Task 3:

# %%
to_convert = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for file in to_convert:
    old_name = file
    new_name = rename_my_file(old_name)
    print(f"{old_name} ----> {new_name}")
# Out:
# oct-08_singapore.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# jul-10_cairo.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# may-15_dhaka.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# may-13_cairo.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# oct-21_cairo.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# jan-10_singapore.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# jun-20_tokyo.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# aug-06_jakarta.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# dec-21_karachi.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt
# jan-01_tokyo.txt ----> ../os-collaboration-exercise-data/11-19-melbourne.txt

# %% [markdown]
# Task 4:

# %%
import glob
def rename_files(directory):
    pattern = os.path.join(directory,'*.txt')
    for file_path in glob.glob(pattern):
        dir_name, file_name = os.path.split(file_path)
        root, extension = os.path.splitext(file_name)
        parts = root.split('-')
        st =''
        for i in parts[1]:
            if i=='_':
                st+='-'
            else:
                st+=i
        new_file_path = os.path.join(dir_name,parts[0]+st+'.txt')
        os.rename(file_path, new_file_path)
        #print(f"Renamed '{file_path}' to '{new_file_path}'")
rename_files(source_directory)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[99], line 17
#      15         os.rename(file_path, new_file_path)
#      16         #print(f"Renamed '{file_path}' to '{new_file_path}'")
# ---> 17 rename_files(source_directory)
#
# Cell In[99], line 9, in rename_files(directory)
#       7 parts = root.split('-')
#       8 st =''
# ----> 9 for i in parts[1]:
#      10     if i=='_':
#      11         st+='-'
#
# IndexError: list index out of range

# %% [markdown]
# Task 5:

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for city in cities:
    city_directory = os.path.join(source_directory,city)
    if not os.path.exists(city_directory):
        os.makedirs(city_directory)

# %% [markdown]
# Task 6:

# %%
pattern = os.path.join(source_directory,'*Cairo')
print(glob.glob(pattern))
# Out:
# ['../os-collaboration-exercise-data/Cairo']
