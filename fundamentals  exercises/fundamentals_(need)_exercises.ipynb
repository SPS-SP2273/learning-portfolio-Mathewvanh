# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Fundamentals (Need) Exercises</span></div>

# %% [markdown]
# 1. Functions(user defined by the def keyword)
# 2. Indentations are important
# 3. Comments start with a #
# 4. = is not the same as ==, the former is an overload function while the latter is to check for equality of value.(different from is operator which checks for memory address equality).
# 5. if not in parenthesise, it can be a variable, e.g. age = 12. Is a variable age that has a integer value 12. Whereas, 'age' is a string and cannot be assigned a value of 12. You could in theory have a string 'age is 12'.
# 6. [] creates a list of objects. {} creates a dictionary that can store key, value pairs that allow the value to be accessed by calling its key. [] creates lists that are accessible through their indexes which is 0-indexed.
# 7. the dot operator allows for functions to be called on instances of specific types of objects. For example, one can compute the square root on 4 by calling np.sqrt(4). After ofc importing the numpy package via:
# ```
# import numpy as np
# ```

# %%
import numpy as np

# %%
x, y = 3, 4
z = np.sqrt(x*2 + y**2)
print(x, y, z)
# Out:
# 3 4 4.69041575982343

# %% [markdown]
# 1. Takes inputs, does something, returns output.
# 2. The inputs for a function
# 3. What is going on in the code?
# 4. Make code look pretty and to define what's inside a function?
# 5. Make python do many many things.
# 6. Call a function.
# 7. What is the function about?
# 8. An empty list.
# 9. An empty list within an empty list within an empty list.(A triple nested list)
# 10. A empty dictionary.

# %%
5/2 #divides 5 by 2 and returns a float with decimal values,defauls is 14 decmial placese in numpy
5//2 # devides 5 by 2 and rounds it down to the neares integer value
5%2 #outputs the remainder when one divides 5 by 2
